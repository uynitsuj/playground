# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
filename = 'data.csv'
data = np.genfromtxt(filename, delimiter=",", usecols=(1, 4), names=True)
data
plt.plot(data['sqft_living'],data['price'], 'o')
#plt.savefig(filename+".png")
